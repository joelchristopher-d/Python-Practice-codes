# %%
class Market():
    def __init__(self):
        self.a = []
        self.cost = []
        self.b=-1
        self.c = ["coke","pepsi","7up","slice"]
        self.d = [10,20,30,40]
    def add(self):
        while(True):
            add = int(input("1.add 5.break"))
            if add == 1:
                drinks = int(input("0.coke 1.pepsi 2.7up 3.slice"))
                self.a[self.b].append(self.c[drinks])
                self.cost[self.b].append(self.d[drinks])
            if add == 5:
                print(self.a[self.b])
                print(sum(self.cost[self.b]))
                break
                        
    def login(self):
        self.b+=1
        print(f"your id {self.b}")
        self.a.append([])
        self.cost.append([])
        obj.add()
        
    def delete(self):
        idd = int(input("enter your id"))
        if idd < len(self.a):
            print(f" ur items: {self.a[idd]}")
        else:
            print("sorry")
            
        


obj = Market()
while(True):
    log = int(input("press 1 to login, 2 to delete"))
    if (log == 1):
        while(True):
            ac = int(input("1.add 3.logout"))
            if ac == 1:
                obj.login()
            elif ac == 2:
#                 obj.del()
                pass
            elif ac == 3:
                break
    elif log == 2:
        obj.delete()
# Out:
# press 1 to login, 2 to delete1
# 1.add 3.logout1
# your id 0
# 1.add 2.break1
# 0.coke 1.pepsi 2.7up 3.slice0
# 1.add 2.break1
# 0.coke 1.pepsi 2.7up 3.slice1
# 1.add 2.break1
# 0.coke 1.pepsi 2.7up 3.slice1
# 1.add 2.break2
# ['coke', 'pepsi', 'pepsi']
# 50

# %%
class SuperMarket():
    def __init__(self):
        self.items = ["Pringles", "milk maid", "Ferrero_Rocher"]
        self.quantity = [50,50,1000]
        self.price = [90,125,500]
        self.id = -1
        self.customer = []
        self.total = []
        
    def Checkavailabilty(self):
        for i in range(len(self.items)):
            print(f"Item Name :{self.items[i]}\nQuantity:{self.quantity[i]}\nPrice:{self.price[i]}\n\n")
            
    def AddItem(self):
        self.which_item = int(input("0.Pringles\n1.milk maid\n2.Ferrero_Rocher\n"))
        if self.which_item<len(self.items):
            self.addquantity = int(input(f"enter {self.items[self.which_item]} quantity"))
            self.quantity[self.which_item]+=self.addquantity
            
    def RemoveItem(self):
        self.which_item = int(input("0.Pringles\n1.milk maid\n2.Ferrero_Rocher\n"))
        if self.which_item<len(self.items):
            self.rquantity = int(input(f"enter {self.items[self.which_item]} quantity"))
            if self.rquantity<=self.quantity[self.which_item]:
                self.quantity[self.which_item]-=self.rquantity
            
            
sm = SuperMarket()
while(True):
    log = int(input("press 1 to login\n2 to delete\n3 to monica\n"))
    if (log == 3):
        while(True):
            select = int(input("1.Checkavailabilty\n2.AddItem\n3.RemoveItem\n"))
            if select == 1:
                sm.Checkavailabilty()
            elif select == 2:
                sm.AddItem()
            elif select == 3:
                sm.RemoveItem()
            else:
                break
# Out:
# press 1 to login
# 2 to delete
# 3 to monica
# 3
# 1.Checkavailabilty
# 2.AddItem
# 3.RemoveItem
# 3
# 0.Pringles
# 1.milk maid
# 2.Ferrero_Rocher
# 1
# enter milk maid quantity2
# 1.Checkavailabilty
# 2.AddItem
# 3.RemoveItem
# 1
# Item Name :Pringles
# Quantity:50
# Price:90
#
#
# Item Name :milk maid
# Quantity:48
# Price:125
#
#
# Item Name :Ferrero_Rocher
# Quantity:1000
# Price:500
